# %% [markdown]
# # 偏差方差权衡

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **模型误差 = 偏差 + 方差 + 不可避免的误差(比如数据本来具有噪音)**

# %% [markdown]
# ## 偏差

# %% [markdown]
# 导致偏差的主要原因:
#   1. 对问题本身的假设不正确, 如非线性数据使用线性回归
#   2. 选择了错误的特征, 如预测考试成绩用学生姓名

# %% [markdown]
# **欠拟合**

# %% [markdown]
# ## 方差

# %% [markdown]
# 数据的一点点扰动都会较大地影响模型
#
# 通常原因: 使用的模型太复杂, 如高阶多项式回归

# %% [markdown]
# **过拟合**

# %% [markdown]
# ## Tips

# %% [markdown]
# **有一些算法天生就是高方差的算法, 如 kNN**
#   - 非参数学习通常都是高方差算法, 因为不对数据进行任何假设
#
# **有一些算法天生就是高偏差的算法, 如线性回归**
#   - 参数学习通常都是高偏差算法, 因为对数据具有极强的假设

# %% [markdown]
# **大多数算法具有相应的参数, 可以调整偏差和方差, 如 kNN 中的 k, 如线性回归中使用多项式回归**

# %% [markdown]
# **偏差和方差通常是矛盾的**
#   - 降低偏差, 会提高方差
#   - 降低方差, 会提高偏差

# %% [markdown]
# **机器学习的主要挑战, 来自于方差**
#
# 解决高方差的通常手段:
#   1. 降低模型复杂度
#   2. 减少数据维度; 降噪
#   3. 增加样本数
#   4. 使用验证集
#   5. **模型正则化**
